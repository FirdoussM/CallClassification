# %%
import json
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer # type: ignore
import assemblyai as aai # type: ignore
import os

# %%
aai.settings.api_key = "e070a4a185a04229ade545eede53ce1b"
transcriber = aai.Transcriber()
transcript = transcriber.transcribe("Emergency_call_dataset/call_105_0.wav")

# %%
print(transcript.text)
audio = [str(transcript)]
# Out:
# I'm walking in the field. I don't know where I am. You're walking in the field. Okay, I need you to just stop, okay? I'm gonna try to find.

# %%
analyzer = SentimentIntensityAnalyzer()

# %%
def transcribe_folder(folder_path):
    transcriptions = {}
    for filename in os.listdir(folder_path):
        if filename.endswith(".wav") or filename.endswith(".mp3"):
            file_path = os.path.join(folder_path, filename)
            text = transcriber.transcribe(str(file_path))
            transcriptions[filename] = text.text
    return transcriptions

# %%
folder_path = "Emergency_call_dataset"
text_data = transcribe_folder(folder_path=folder_path)

# %%
text_data['call_154_0.wav'].text
# Out:
# 'I help you? Hi, this is Leticia from store big five on Green Valley. I have a person that is robbing me.'

# %%
text_data
# Out:
# {'call_100_0.wav': 'One day.',
#  'call_101_0.wav': "This is the Bulkovia bank of 13 two west International speedway boulevard. Okay. We're being robbed.",
#  'call_102_0.wav': '',
#  'call_103_0.wav': "Yes, we're at the Nelson building, and there's some man here with adults who came into the board meeting. Okay, you're at.",
#  'call_104_0.wav': "Listen, we're really bad, okay? You got attacked by people.",
#  'call_104_1.wav': '',
#  'call_105_0.wav': "I'm walking in the field. I don't know where I am. You're walking in the field. Okay, I need you to just stop, okay? I'm gonna try to find.",
#  'call_106_0.wav': "Emergency. Somebody just sent the police officer. Okay, what's the address, ma'am? He's.",
#  'call_106_1.wav': 'Emergency. I got an officer been shot down here off Oliver.',
#  'call_106_2.wav': '',
#  'call_106_3.wav': 'He just got.',
#  'call_107_0.wav': "I'm in a white Honda and my car doesn't want to turn off.",
# ...

# %%
import pandas as pd
df = pd.DataFrame(list(text_data.items()), columns=['Filename', 'Transcription'])

# %%
df.to_csv("Emergency_Call_data.csv")

# %%
df.head()
# Out:
#          Filename                                      Transcription
# 0  call_100_0.wav                                           One day.
# 1  call_101_0.wav  This is the Bulkovia bank of 13 two west Inter...
# 2  call_102_0.wav
# 3  call_103_0.wav  Yes, we're at the Nelson building, and there's...
# 4  call_104_0.wav  Listen, we're really bad, okay? You got attack...
